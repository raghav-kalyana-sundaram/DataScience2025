# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rate_puf = pd.read_csv('../Files/Rate_PUF.csv')
rate_puf.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2023        WA     21989       HIOS  2022-11-19 01:01:13
# 1          2023        AK     21989       HIOS  2022-11-19 01:01:13
# 2          2023        AK     21989       HIOS  2022-11-19 01:01:13
# 3          2023        AK     21989       HIOS  2022-11-19 01:01:13
# 4          2023        AK     21989       HIOS  2022-11-19 01:01:13
#
#   RateEffectiveDate RateExpirationDate          PlanId   RatingAreaId Tobacco  \
# 0        2023-10-01         2023-12-31  21989AK0110001  Rating Area 1     NaN
# 1        2023-01-01         2023-03-31  21989AK0110001  Rating Area 1     NaN
# 2        2023-04-01         2023-06-30  21989AK0110001  Rating Area 1     NaN
# 3        2023-07-01         2023-09-30  21989AK0110001  Rating Area 1     NaN
# 4        2023-07-01         2023-09-30  21989AK0110001  Rating Area 2     NaN
#
#              Age  IndividualRate  IndividualTobaccoRate  Couple  \
# ...

# %%
rate_puf= rate_puf[rate_puf["Age"] == "Family Option"]
rate_puf
# Out:
#          BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0                2023        WA     21989       HIOS  2022-11-19 01:01:13
# 1                2023        AK     21989       HIOS  2022-11-19 01:01:13
# 2                2023        AK     21989       HIOS  2022-11-19 01:01:13
# 3                2023        AK     21989       HIOS  2022-11-19 01:01:13
# 4                2023        AK     21989       HIOS  2022-11-19 01:01:13
# ...               ...       ...       ...        ...                  ...
# 2709290          2023        VA     69103      SERFF  2022-08-15 20:01:00
# 2709291          2023        VA     69103      SERFF  2022-08-15 20:01:00
# 2709292          2023        VA     69103      SERFF  2022-08-15 20:01:00
# 2709293          2023        VA     69103      SERFF  2022-08-15 20:01:00
# 2709294          2023        VA     69103      SERFF  2022-08-15 20:01:00
#
#         RateEffectiveDate RateExpirationDate          PlanId    RatingAreaId  \
# ...

# %%
df = rate_puf[["IndividualRate", "Couple", "PrimarySubscriberAndOneDependent", "PrimarySubscriberAndTwoDependents","PrimarySubscriberAndThreeOrMoreDependents", "CoupleAndOneDependent", "CoupleAndTwoDependents", "CoupleAndThreeOrMoreDependents"]]

# %%
plt.bar(df.columns, df.mean())
plt.xticks(rotation=90)
plt.ylabel("Average Rate") 
plt.title("Average Rate for Family Option")
plt.show()
